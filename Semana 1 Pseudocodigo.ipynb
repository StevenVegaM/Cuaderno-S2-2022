# %% [markdown]
# <a href="https://colab.research.google.com/github/StevenVegaM/Cuaderno-S2-2022/blob/main/Semana%201%20Pseudocodigo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Semana 1 - Pseudocódigo
# ### Contador de digitos
# Usando Pseint para crear un diagrama de flujo y un pseudocódigo para representar el proceso de un algoritmo para contar digitos
#
#      -  Recibira  dos parametros
#      -  Ambos mayores a cero

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ```
# Algoritmo contarDigitos
# 	Total = 0
# 	Leer a
# 	Mientras a > 0 Hacer
# 		a = trunc(a/10)
# 		total = total + 1
# 	FinMientras
# 	Escribir Total
# FinAlgoritmo
# ```

# %% [markdown]
# # Calcular Iva
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ```
# Algoritmo calcularIVA
# 	Leer precioProducto
# 	Leer cantidad
# 	total = precioProducto + cantidad
# 	total = total * 1.13
# 	Escribir total
# FinAlgoritmo
# ```

# %% [markdown]
# # Comparar numeros
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ```
# Algoritmo sin_titulo
# 	Leer a
# 	Leer b
# 	Si a > b Entonces
# 		Escribir a
# 	SiNo
# 		Escribir 0
# 	FinSi
# FinAlgoritmo
# ```
