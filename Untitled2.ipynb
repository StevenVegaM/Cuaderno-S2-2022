# %% [markdown]
# <a href="https://colab.research.google.com/github/StevenVegaM/Cuaderno-S2-2022/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Semana 2 - ejercicios

# %% [markdown]
# ###ejercicio 1
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ```
# Algoritmo sin_titulo
# 	Leer N1
# 	Leer N2
# 	Leer N3
# 	Leer N4
# 	suma = N1 + N2 + N3 + N4
# 	resultado = suma / 4
# 	Escribir resultado
# FinAlgoritmo
# ```

# %% [markdown]
# ```
# def prom():
#     n1 = int(input(" Valor del primer numero: "))
#     n2 = int(input(" Valor del segundo numero: "))
#     n3 = int(input(" Valor del tercer numero: "))
#     n4 = int(input(" Valor del cuarto numero: "))
#     suma = n1 + n2 + n3 + n4
#     resultado = suma / 4
#     return resultado
# ```

# %% [markdown]
# ###ejercicio 2
# ![image.png](data:image/png;base64,...)
#
#
#
# ```
# Algoritmo volumenCaja
# 	Leer largo
# 	Leer ancho
# 	Leer alto
# 	volumen = largo * ancho * alto
# 	Escribir volumen
# FinAlgoritmo
#
# ```
#
#
#
# ```
# def volumenCaja():
#     largo = int(input("ingrese el largo: "))
#     ancho = int(input("ingrese el ancho: "))
#     alto =  int(input("ingrese el alto: "))
#     volumen = largo * ancho * alto
#     return volumen
# ```

# %% [markdown]
# #ejercicio 3
#
# ![image.png](data:image/png;base64,...)
#
#
#
# ```
# Algoritmo Areacirc
# 	Leer radio
# 	p <- 3.14
# 	area <- p*radio^2
# 	Escribir area
# FinAlgoritmo
# ```
#
#
# ```
# def areaCirc():
#     radio = int(input("Valor del radio: "))
#     pi = 3.14
#     area = pi * radio ** 2
#     return area
# ```

# %% [markdown]
# #ejercicio 6
# ![image.png](data:image/png;base64,...)
#
#
#
# ```
# Algoritmo edadVotos
# 	Leer edad
# 	a = "puede votar"
# 	b = "no puede votar"
# 	Si edad > 18 Entonces
# 		Escribir a
# 	SiNo
# 		Escribir b
# 	FinSi
# FinAlgoritmo
# ```
#
#
# ```
# def edadVotos():
#     edad = int(input("Ingresar edad: "))
#     if edad < 18:
#         return "No puede votar"
#     else:
#         return "Puede votar"
# ```

# %% [markdown]
# #ejercicio 7
#
# ![image.png](data:image/png;base64,...)
#
#
#
# ```
# Algoritmo trajes
# 	Leer precioTraje
# 	descuento1 = 0.15
# 	descuento2 = 0.08
# 	Si precioTraje > 2500 Entonces
# 		a = precioTraje * descuento1
# 		res1 = precioTraje - a
# 		Escribir res1
# 	SiNo
# 		b = precioTraje * descuento2
# 		res2 = precioTraje - b
# 		Escribir res2
# 	FinSi
# FinAlgoritmo
# ```
#
#
# ```
# def trajes():
#     precio = int(input("Cual es el precio: "))
#     descuento1 = 0.15
#     descuento2 = 0.08
#     if precio > 2500:
#         a = precio * descuento1
#         precio -= a
#         return precio
#     else:
#         b = precio * descuento2
#         precio -= b
#         return precio
# ```

# %% [markdown]
# #ejercicio 8
# ![image.png](data:image/png;base64,...)
#
#
#
# ```
# Algoritmo restaurante
# 	Leer personas
# 	Si personas < 5 Entonces
# 		plato = 9500
# 		total = plato * personas
# 		Escribir total
# 	FinSi
# 	Si personas >= 5 y personas <= 10 Entonces
# 		plato = 8500
# 		total = plato * personas
# 		Escribir total
# 	FinSi
# 	Si personas > 10 Entonces
# 		plato = 7500
# 		total = plato * personas
# 		Escribir total
# 	FinSi
# FinAlgoritmo
# ```
#
#
# ```
# def restaurante():
#     plato = 0
#     total = 0
#     personas = int(input("Cantidad de personas: "))
#     if personas <= 0:
#         return "Erro: la cantidad de personas debe ser mayor a CERO"
#     if personas < 5:
#         plato = 9500
#         total = plato * personas
#         return total
#     if personas >= 5 and personas <= 10:
#         plato = 8500
#         total = plato * personas
#         return total
#     if peronas >= 11:
#         plato = 7500
#         total = plato * personas
#         return total
# ```

# %% [markdown]
# #ejercicio 9
#
# ![image.png](data:image/png;base64,...)
#
#
#
# ```
# Algoritmo numPar
# 	Leer numero
# 	Si numero % 2 = 0 Entonces
# 		Escribir "True"
# 	SiNo
# 		Escribir "False"
# 	FinSi
# FinAlgoritmo
# ```
#
#
#
# ```
# def numPar(numero):
#     if numero % 2 == 0:
#         return "True"
#     else:
#         return "False"
# ```

# %% [markdown]
# #ejercicio 12-B
#
# ![image.png](data:image/png;base64,...)
#
#
# ```
# Algoritmo contarPares
# 	resultado <- 0
# 	Leer num
# 	Si num>0 Entonces
# 		Mientras num > 0 Hacer
# 			num <- num
# 			digito <- num MOD 10
# 			Si digito MOD 2=0 Entonces
# 				resultado <- resultado+1
# 			FinSi
# 		FinMientras
# 		Escribir resultado
# 	FinSi
# FinAlgoritmo
# ```
#
#
#
# ```
# def contarPares(num):
#     resultado = 0
#     if(num>0):
#         while(num>0):
#             digito = num % 10
#             num = num // 10
#
#             if (digito % 2) == 0:
#                 resultado += 1
#     else:
#         resultado + 1
#     return resultado
# ```

# %% [markdown]
# #ejercicio Factorial
#
# ![image.png](data:image/png;base64,...)
#
#
# ```
# Algoritmo factorial
# 	resultado = 1
# 	mult = 1
# 	Si num >= 0 Entonces
# 		Mientras mult <= num Hacer
# 			resultado = resultado * mult
# 			mult = mult + 1
# 		FinMientras
# 		Escribir resultado
# 	SiNo
# 		Escribir 'x'
# 	FinSi
# FinAlgoritmo
# ```
#
#
# ```
# def Factorial (num):
#     mult = 1
#     resultado = 1
#     if isinstance(num, int):
#         if num >= 0:
#             while (mult <= num):
#                 resultado = resultado * mult
#                 mult = mult + 1
#             return resultado
# ```

# %% [markdown]
# #ejercicio 2 digitos
#
# ![image.png](data:image/png;base64,...)
#
# ```
# Algoritmo dosDigitos
# 	resultado = 0
# 	Leer valor
# 	Mientras valor > 0 Hacer
# 		a = valor % 100
# 		valor = valor // 100
# 		resultado = resultado + 1
# 	FinMientras
# 	Escribir resultado
# FinAlgoritmo
# ```
#
#
# ```
# def dosDigitos(valor):
#     resultado = 0
#     while valor > 0:
#         a = valor % 100
#         valor = valor // 100
#         resultado +=1
#     return resultado
# ```
